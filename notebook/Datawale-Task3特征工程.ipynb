# %% [markdown]
# 1. 特征清洗：异常值、缺失值处理
# 2. 特征构造：数据分桶，特征归一化、标准化，其他
# 3. 特征筛选、特征降维PCA

# %%
# 各种函数库
#coding:utf-8
#导入warnings包，利用过滤器来实现忽略警告语句。
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
# 读取数据
# path = "./datalab/231784/"
path = "../Data/"
Train_data = pd.read_csv(path+'used_car_train_20200313.csv', sep=' ')
Test_data = pd.read_csv(path+'used_car_testA_20200313.csv', sep=' ')

# %% [markdown]
# 1. 特征清洗
# 1）缺失值处理

# %%
missing_list = ['bodyType','fuelType','gearbox']

# %%
b = Train_data[missing_list].apply(pd.value_counts)
b.plot(kind='pie',subplots=True, figsize=(16, 16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0ee254a1d0>,
# ...
#       dtype=object)

# %%
# 使用众数填充
for col_miss in missing_list:
    hp_all_num_fillmean[col_no].fillna(hp_all_num_fillmean[col_no].mean(), inplace=True)
